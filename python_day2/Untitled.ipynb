# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
countries = glob.glob('../shell-lessons/data/gapminder_data/gapminder_by_country/*.cc.txt')

# %%
pwd
# Out:
# 'C:\\Users\\Bensk\\Desktop\\SDC_02-15-2020\\2020_February_Bash_Python\\python_day2'

# %%
ls "../shell-lessons/data/gapminder_data/gapminder_by_country/"
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 7621-9EDA
#
#  Directory of C:\Users\Bensk\Desktop\SDC_02-15-2020\2020_February_Bash_Python\shell-lessons\data\gapminder_data\gapminder_by_country
#
# 02/15/2020  10:54 AM    <DIR>          .
# 02/15/2020  10:54 AM    <DIR>          ..
# 02/15/2020  10:54 AM               604 Afghanistan.cc.txt
# 02/15/2020  10:54 AM               563 Albania.cc.txt
# 02/15/2020  10:54 AM               586 Algeria.cc.txt
# 02/15/2020  10:54 AM               562 Angola.cc.txt
# 02/15/2020  10:54 AM               633 Argentina.cc.txt
# 02/15/2020  10:54 AM               610 Australia.cc.txt
# 02/15/2020  10:54 AM               559 Austria.cc.txt
# 02/15/2020  10:54 AM               536 Bahrain.cc.txt
# 02/15/2020  10:54 AM               604 Bangladesh.cc.txt
# 02/15/2020  10:54 AM               565 Belgium.cc.txt
# 02/15/2020  10:54 AM               548 Benin.cc.txt
# 02/15/2020  10:54 AM               596 Bolivia.cc.txt
# ...

# %%
countries
# Out:
# ['../shell-lessons/data/gapminder_data/gapminder_by_country\\Afghanistan.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Albania.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Algeria.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Angola.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Argentina.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Australia.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Austria.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bahrain.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bangladesh.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Belgium.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Benin.cc.txt',
#  '../shell-lessons/data/gapminder_data/gapminder_by_country\\Bolivia.cc.txt',
# ...

# %%
countries[1]
# Out:
# '../shell-lessons/data/gapminder_data/gapminder_by_country\\Albania.cc.txt'

# %% [markdown]
# 1. for loop to import each file into pandas
# 2. Concatenate all files into a dataframe
# 3. Save the files

# %%
df = pd.DataFrame()

for country in countries:
    c = pd.read_csv(country, sep='\t',header=None)
    df = df.append(c, ignore_index=True)

# %%
df
# Out:
#                 0     1            2       3       4        5
# 0     Afghanistan  1997  2.22274e+07    Asia  41.763  635.341
# 1     Afghanistan  2002  2.52684e+07    Asia  42.129  726.734
# 2     Afghanistan  2007  3.18899e+07    Asia  43.828   974.58
# 3     Afghanistan  1952  8.42533e+06    Asia  28.801  779.445
# 4     Afghanistan  1957  9.24093e+06    Asia  30.332  820.853
# ...           ...   ...          ...     ...     ...      ...
# 1700     Zimbabwe  1987      9216418  Africa  62.351  706.157
# 1701     Zimbabwe  1992     10704340  Africa  60.377  693.421
# 1702     Zimbabwe  1997     11404948  Africa  46.809   792.45
# 1703     Zimbabwe  2002     11926563  Africa  39.989  672.039
# 1704     Zimbabwe  2007     12311143  Africa  43.487  469.709
#
# [1705 rows x 6 columns]

# %%
for item in countries:
    if item.endswith("country.cc.txt"):
        print('found it')
        countries.remove(item)
# Out:
# found it

# %%
for item in countries:
    if item.endswith("country.cc.txt"):
        print('found it')

# %%
df = pd.DataFrame()

for country in countries:
    c = pd.read_csv(country, sep='\t',header=None)
    df = df.append(c, ignore_index=True)
    
df
# Out:
#                 0     1           2       3       4           5
# 0     Afghanistan  1997  22227415.0    Asia  41.763  635.341351
# 1     Afghanistan  2002  25268405.0    Asia  42.129  726.734055
# 2     Afghanistan  2007  31889923.0    Asia  43.828  974.580338
# 3     Afghanistan  1952   8425333.0    Asia  28.801  779.445314
# 4     Afghanistan  1957   9240934.0    Asia  30.332  820.853030
# ...           ...   ...         ...     ...     ...         ...
# 1699     Zimbabwe  1987   9216418.0  Africa  62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0  Africa  60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0  Africa  46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0  Africa  39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0  Africa  43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.shape[0]
# Out:
# 1704

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df.columns = ['Country','Year','Population','Continent',
              'LifeExp','gdpPercap']

# %%
df
# Out:
#           Country  Year  Population Continent  LifeExp   gdpPercap
# 0     Afghanistan  1997  22227415.0      Asia   41.763  635.341351
# 1     Afghanistan  2002  25268405.0      Asia   42.129  726.734055
# 2     Afghanistan  2007  31889923.0      Asia   43.828  974.580338
# 3     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 4     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df
# Out:
#           Country  Year  Population Continent  LifeExp   gdpPercap
# 0     Afghanistan  1997  22227415.0      Asia   41.763  635.341351
# 1     Afghanistan  2002  25268405.0      Asia   42.129  726.734055
# 2     Afghanistan  2007  31889923.0      Asia   43.828  974.580338
# 3     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 4     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df = df[['Continent','Country','Year','Population',
         'LifeExp','gdpPercap']]

# %%
df
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1         Asia  Afghanistan  2002  25268405.0   42.129  726.734055
# 2         Asia  Afghanistan  2007  31889923.0   43.828  974.580338
# 3         Asia  Afghanistan  1952   8425333.0   28.801  779.445314
# 4         Asia  Afghanistan  1957   9240934.0   30.332  820.853030
# ...        ...          ...   ...         ...      ...         ...
# 1699    Africa     Zimbabwe  1987   9216418.0   62.351  706.157306
# 1700    Africa     Zimbabwe  1992  10704340.0   60.377  693.420786
# 1701    Africa     Zimbabwe  1997  11404948.0   46.809  792.449960
# 1702    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by=['Country']).reset_index(drop=True)
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1         Asia  Afghanistan  1992  16317921.0   41.674  649.341395
# 2         Asia  Afghanistan  1987  13867957.0   40.822  852.395945
# 3         Asia  Afghanistan  1982  12881816.0   39.854  978.011439
# 4         Asia  Afghanistan  1972  13079460.0   36.088  739.981106
# ...        ...          ...   ...         ...      ...         ...
# 1699    Africa     Zimbabwe  1957   3646340.0   50.469  518.764268
# 1700    Africa     Zimbabwe  1952   3080907.0   48.451  406.884115
# 1701    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1702    Africa     Zimbabwe  1972   5861135.0   55.635  799.362176
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by=['LifeExp','Continent','Country']).reset_index(drop=True)
# Out:
#      Continent           Country  Year   Population  LifeExp     gdpPercap
# 0       Africa            Rwanda  1992    7290203.0   23.599    737.068595
# 1         Asia       Afghanistan  1952    8425333.0   28.801    779.445314
# 2       Africa            Gambia  1952     284320.0   30.000    485.230659
# 3       Africa            Angola  1952    4232095.0   30.015   3520.610273
# 4       Africa      Sierra Leone  1952    2143249.0   30.331    879.787736
# ...        ...               ...   ...          ...      ...           ...
# 1699    Europe       Switzerland  2007    7554661.0   81.701  37506.419070
# 1700    Europe           Iceland  2007     301931.0   81.757  36180.789190
# 1701      Asia             Japan  2002  127065841.0   82.000  28604.591900
# 1702      Asia  Hong Kong, China  2007    6980412.0   82.208  39724.978670
# 1703      Asia             Japan  2007  127467972.0   82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by=['Country']).reset_index(drop=True)
# Out:
#      Continent      Country  Year  Population  LifeExp   gdpPercap
# 0         Asia  Afghanistan  1997  22227415.0   41.763  635.341351
# 1         Asia  Afghanistan  1992  16317921.0   41.674  649.341395
# 2         Asia  Afghanistan  1987  13867957.0   40.822  852.395945
# 3         Asia  Afghanistan  1982  12881816.0   39.854  978.011439
# 4         Asia  Afghanistan  1972  13079460.0   36.088  739.981106
# ...        ...          ...   ...         ...      ...         ...
# 1699    Africa     Zimbabwe  1957   3646340.0   50.469  518.764268
# 1700    Africa     Zimbabwe  1952   3080907.0   48.451  406.884115
# 1701    Africa     Zimbabwe  2002  11926563.0   39.989  672.038623
# 1702    Africa     Zimbabwe  1972   5861135.0   55.635  799.362176
# 1703    Africa     Zimbabwe  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.to_csv('gapminder_all.csv')
#use different name, otherwise will be rewritten without warning!!!

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 7621-9EDA
#
#  Directory of C:\Users\Bensk\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 02/16/2020  04:01 PM    <DIR>          .
# 02/16/2020  04:01 PM    <DIR>          ..
# 02/16/2020  01:23 PM    <DIR>          .ipynb_checkpoints
# 02/16/2020  04:02 PM           101,493 gapminder_all.csv
# 02/16/2020  03:56 PM               445 gapminder_summ_stats.csv
# 02/16/2020  03:56 PM            80,462 oceania_bar.png
# 02/16/2020  01:08 PM            19,756 Review_of_Python.ipynb
# 02/16/2020  03:56 PM               445 two_countries_summ_stats.csv
# 02/16/2020  04:01 PM           374,716 Untitled.ipynb
#                6 File(s)        577,317 bytes
#                3 Dir(s)  856,169,885,696 bytes free

# %%
df.describe()
# Out:
#              Year    Population      LifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165877
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846989
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.describe().to_csv('gapminder_summ_stats.csv')

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 7621-9EDA
#
#  Directory of C:\Users\Bensk\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 02/16/2020  04:01 PM    <DIR>          .
# 02/16/2020  04:01 PM    <DIR>          ..
# 02/16/2020  01:23 PM    <DIR>          .ipynb_checkpoints
# 02/16/2020  04:02 PM           101,493 gapminder_all.csv
# 02/16/2020  04:02 PM               445 gapminder_summ_stats.csv
# 02/16/2020  03:56 PM            80,462 oceania_bar.png
# 02/16/2020  01:08 PM            19,756 Review_of_Python.ipynb
# 02/16/2020  03:56 PM               445 two_countries_summ_stats.csv
# 02/16/2020  04:01 PM           374,716 Untitled.ipynb
#                6 File(s)        577,317 bytes
#                3 Dir(s)  856,169,885,696 bytes free

# %% [markdown]
# # Slicing
#
# `.loc[]` to select values by the name
#
# `.loc[a:b:i:j]`, where
#
# a and b are the rows/countries
#
# i and j or the columns/years

# %%
df = df.set_index('Country')
df
# Out:
#             Continent  Year  Population  LifeExp   gdpPercap
# Country
# Afghanistan      Asia  1997  22227415.0   41.763  635.341351
# Afghanistan      Asia  2002  25268405.0   42.129  726.734055
# Afghanistan      Asia  2007  31889923.0   43.828  974.580338
# Afghanistan      Asia  1952   8425333.0   28.801  779.445314
# Afghanistan      Asia  1957   9240934.0   30.332  820.853030
# ...               ...   ...         ...      ...         ...
# Zimbabwe       Africa  1987   9216418.0   62.351  706.157306
# Zimbabwe       Africa  1992  10704340.0   60.377  693.420786
# Zimbabwe       Africa  1997  11404948.0   46.809  792.449960
# Zimbabwe       Africa  2002  11926563.0   39.989  672.038623
# Zimbabwe       Africa  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc['Brazil':'Ecuador','Year':'LifeExp']
# Out:
#          Year   Population  LifeExp
# Country
# Brazil   1952   56602560.0   50.917
# Brazil   1957   65551171.0   53.285
# Brazil   1962   76039390.0   55.665
# Brazil   1967   88049823.0   57.632
# Brazil   1972  100840058.0   59.504
# ...       ...          ...      ...
# Ecuador  1987    9545158.0   67.231
# Ecuador  1992   10748394.0   69.613
# Ecuador  1997   11911819.0   72.312
# Ecuador  2002   12921234.0   74.173
# Ecuador  2007   13755680.0   74.994
#
# [288 rows x 3 columns]

# %%
df.loc['Brazil':'Ecuador']
# Out:
#         Continent  Year   Population  LifeExp    gdpPercap
# Country
# Brazil   Americas  1952   56602560.0   50.917  2108.944355
# Brazil   Americas  1957   65551171.0   53.285  2487.365989
# Brazil   Americas  1962   76039390.0   55.665  3336.585802
# Brazil   Americas  1967   88049823.0   57.632  3429.864357
# Brazil   Americas  1972  100840058.0   59.504  4985.711467
# ...           ...   ...          ...      ...          ...
# Ecuador  Americas  1987    9545158.0   67.231  6481.776993
# Ecuador  Americas  1992   10748394.0   69.613  7103.702595
# Ecuador  Americas  1997   11911819.0   72.312  7429.455877
# Ecuador  Americas  2002   12921234.0   74.173  5773.044512
# Ecuador  Americas  2007   13755680.0   74.994  6873.262326
#
# [288 rows x 5 columns]

# %%
df.loc['Brazil']
# Out:
#         Continent  Year   Population  LifeExp    gdpPercap
# Country
# Brazil   Americas  1952   56602560.0   50.917  2108.944355
# Brazil   Americas  1957   65551171.0   53.285  2487.365989
# Brazil   Americas  1962   76039390.0   55.665  3336.585802
# Brazil   Americas  1967   88049823.0   57.632  3429.864357
# Brazil   Americas  1972  100840058.0   59.504  4985.711467
# Brazil   Americas  1977  114313951.0   61.489  6660.118654
# Brazil   Americas  1982  128962939.0   63.336  7030.835878
# Brazil   Americas  1987  142938076.0   65.205  7807.095818
# Brazil   Americas  1992  155975974.0   67.057  6950.283021
# Brazil   Americas  1997  168546719.0   69.388  7957.980824
# Brazil   Americas  2002  179914212.0   71.006  8131.212843
# Brazil   Americas  2007  190010647.0   72.390  9065.800825

# %%
df.loc[['Brazil','Ecuador'],'Year':'LifeExp']
# Out:
#          Year   Population  LifeExp
# Country
# Brazil   1952   56602560.0   50.917
# Brazil   1957   65551171.0   53.285
# Brazil   1962   76039390.0   55.665
# Brazil   1967   88049823.0   57.632
# Brazil   1972  100840058.0   59.504
# Brazil   1977  114313951.0   61.489
# Brazil   1982  128962939.0   63.336
# Brazil   1987  142938076.0   65.205
# Brazil   1992  155975974.0   67.057
# Brazil   1997  168546719.0   69.388
# Brazil   2002  179914212.0   71.006
# Brazil   2007  190010647.0   72.390
# Ecuador  1952    3548753.0   48.357
# Ecuador  1957    4058385.0   51.356
# Ecuador  1962    4681707.0   54.640
# Ecuador  1967    5432424.0   56.678
# Ecuador  1972    6298651.0   58.796
# Ecuador  1977    7278866.0   61.310
# Ecuador  1982    8365850.0   64.342
# Ecuador  1987    9545158.0   67.231
# Ecuador  1992   10748394.0   69.613
# Ecuador  1997   11911819.0   72.312
# Ecuador  2002   12921234.0   74.173
# Ecuador  2007   13755680.0   74.994

# %% [markdown]
# `.iloc[]` to select values by the index
#
# `.iloc[a:b:i:j]`, where
#
# a and b are the indexes of the rows
#
# i and j are the indexes of the columns

# %%
df.iloc[9:16,0:2]
# Out:
#             Continent  Year
# Country
# Afghanistan      Asia  1982
# Afghanistan      Asia  1987
# Afghanistan      Asia  1992
# Albania        Europe  1952
# Albania        Europe  1957
# Albania        Europe  1962
# Albania        Europe  1967

# %% [markdown]
# # CHEEKY EXERCISE!
#
# ## Select two countries of your interest.
#
# ## Slice the `df` to select only these countries.
#
# ## Then obtain summery statistics by country, and save the file

# %%
df.loc[['Brazil','Ecuador']].describe().to_csv('two_countries_summ_stats.csv')

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 7621-9EDA
#
#  Directory of C:\Users\Bensk\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 02/16/2020  04:01 PM    <DIR>          .
# 02/16/2020  04:01 PM    <DIR>          ..
# 02/16/2020  01:23 PM    <DIR>          .ipynb_checkpoints
# 02/16/2020  04:02 PM           101,493 gapminder_all.csv
# 02/16/2020  04:02 PM               445 gapminder_summ_stats.csv
# 02/16/2020  03:56 PM            80,462 oceania_bar.png
# 02/16/2020  01:08 PM            19,756 Review_of_Python.ipynb
# 02/16/2020  04:02 PM               445 two_countries_summ_stats.csv
# 02/16/2020  04:01 PM           374,716 Untitled.ipynb
#                6 File(s)        577,317 bytes
#                3 Dir(s)  856,169,885,696 bytes free

# %% [markdown]
# # Plots

# %%
# %matplotlib inline

# %%
# This is just to make sure wwe all see a plot
time= [0,1,2,3,4]
position= [0,100,200,300,400]
plt.plot(time,position)

# %%
df
# Out:
#             Continent  Year  Population  LifeExp   gdpPercap
# Country
# Afghanistan      Asia  1997  22227415.0   41.763  635.341351
# Afghanistan      Asia  2002  25268405.0   42.129  726.734055
# Afghanistan      Asia  2007  31889923.0   43.828  974.580338
# Afghanistan      Asia  1952   8425333.0   28.801  779.445314
# Afghanistan      Asia  1957   9240934.0   30.332  820.853030
# ...               ...   ...         ...      ...         ...
# Zimbabwe       Africa  1987   9216418.0   62.351  706.157306
# Zimbabwe       Africa  1992  10704340.0   60.377  693.420786
# Zimbabwe       Africa  1997  11404948.0   46.809  792.449960
# Zimbabwe       Africa  2002  11926563.0   39.989  672.038623
# Zimbabwe       Africa  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
gdp_oceania = df.loc[['Australia','New Zealand'],['Year','gdpPercap']]
gdp_oceania
# Out:
#              Year    gdpPercap
# Country
# Australia    1952  10039.59564
# Australia    1957  10949.64959
# Australia    1962  12217.22686
# Australia    1967  14526.12465
# Australia    1972  16788.62948
# Australia    1977  18334.19751
# Australia    1982  19477.00928
# Australia    1987  21888.88903
# Australia    1992  23424.76683
# Australia    1997  26997.93657
# Australia    2002  30687.75473
# Australia    2007  34435.36744
# New Zealand  1952  10556.57566
# New Zealand  1957  12247.39532
# New Zealand  1962  13175.67800
# New Zealand  1967  14463.91893
# New Zealand  1972  16046.03728
# New Zealand  1977  16233.71770
# New Zealand  1982  17632.41040
# New Zealand  1987  19007.19129
# New Zealand  1992  18363.32494
# New Zealand  1997  21050.41377
# New Zealand  2002  23189.80135
# New Zealand  2007  25185.00911

# %%
gdp_oceania_p = pd.pivot_table(gdp_oceania,
               values='gdpPercap', index='Year', columns='Country')
gdp_oceania_p
# Out:
# Country    Australia  New Zealand
# Year
# 1952     10039.59564  10556.57566
# 1957     10949.64959  12247.39532
# 1962     12217.22686  13175.67800
# 1967     14526.12465  14463.91893
# 1972     16788.62948  16046.03728
# 1977     18334.19751  16233.71770
# 1982     19477.00928  17632.41040
# 1987     21888.88903  19007.19129
# 1992     23424.76683  18363.32494
# 1997     26997.93657  21050.41377
# 2002     30687.75473  23189.80135
# 2007     34435.36744  25185.00911

# %%
plt.plot(pd.pivot_table(gdp_oceania, values='gdpPercap',
                        index='Year', columns='Country'))

# %%
plt.plot(gdp_oceania_p)
plt.xlabel('Year') # taking them as integers
plt.ylabel('GDP per capita, $1,000')
plt.title('GAPMINDER')
# Out:
# Text(0.5, 1.0, 'GAPMINDER')

# %%
plt.plot(gdp_oceania_p.loc[:,'Australia'],':k', label='Australia')
plt.plot(gdp_oceania_p.loc[:,'New Zealand'],'r-', label='New Zealand')
plt.legend(loc="best")

# %%
plt.rcParams.update(plt.rcParamsDefault)
gdp_oceania_p.plot()
gdp_oceania_p.plot(kind='barh')
gdp_oceania_p.plot(kind='bar')

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('seaborn-colorblind')
gdp_oceania_p.plot(kind='bar')

# %%
plt.style.use('ggplot')
gdp_oceania_p.plot(kind='bar')
plt.savefig('oceania_bar.png', dpi=300)

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 7621-9EDA
#
#  Directory of C:\Users\Bensk\Desktop\SDC_02-15-2020\2020_February_Bash_Python\python_day2
#
# 02/16/2020  04:01 PM    <DIR>          .
# 02/16/2020  04:01 PM    <DIR>          ..
# 02/16/2020  01:23 PM    <DIR>          .ipynb_checkpoints
# 02/16/2020  04:02 PM           101,493 gapminder_all.csv
# 02/16/2020  04:02 PM               445 gapminder_summ_stats.csv
# 02/16/2020  04:02 PM            68,030 oceania_bar.png
# 02/16/2020  01:08 PM            19,756 Review_of_Python.ipynb
# 02/16/2020  04:02 PM               445 two_countries_summ_stats.csv
# 02/16/2020  04:01 PM           374,716 Untitled.ipynb
#                6 File(s)        564,885 bytes
#                3 Dir(s)  856,169,897,984 bytes free

# %%
# ?plt.savefig

# %%
df
# Out:
#             Continent  Year  Population  LifeExp   gdpPercap
# Country
# Afghanistan      Asia  1997  22227415.0   41.763  635.341351
# Afghanistan      Asia  2002  25268405.0   42.129  726.734055
# Afghanistan      Asia  2007  31889923.0   43.828  974.580338
# Afghanistan      Asia  1952   8425333.0   28.801  779.445314
# Afghanistan      Asia  1957   9240934.0   30.332  820.853030
# ...               ...   ...         ...      ...         ...
# Zimbabwe       Africa  1987   9216418.0   62.351  706.157306
# Zimbabwe       Africa  1992  10704340.0   60.377  693.420786
# Zimbabwe       Africa  1997  11404948.0   46.809  792.449960
# Zimbabwe       Africa  2002  11926563.0   39.989  672.038623
# Zimbabwe       Africa  2007  12311143.0   43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
subset_yr = df.reset_index().loc[:,['Year','gdpPercap','Country']]
subset_yr
# Out:
#       Year   gdpPercap      Country
# 0     1997  635.341351  Afghanistan
# 1     2002  726.734055  Afghanistan
# 2     2007  974.580338  Afghanistan
# 3     1952  779.445314  Afghanistan
# 4     1957  820.853030  Afghanistan
# ...    ...         ...          ...
# 1699  1987  706.157306     Zimbabwe
# 1700  1992  693.420786     Zimbabwe
# 1701  1997  792.449960     Zimbabwe
# 1702  2002  672.038623     Zimbabwe
# 1703  2007  469.709298     Zimbabwe
#
# [1704 rows x 3 columns]

# %%
subset_yr = subset_yr[subset_yr['Year'].isin ([1952,2007])]
subset_yr
# Out:
#       Year    gdpPercap      Country
# 2     2007   974.580338  Afghanistan
# 3     1952   779.445314  Afghanistan
# 12    1952  1601.056136      Albania
# 23    2007  5937.029526      Albania
# 29    1952  2449.008185      Algeria
# ...    ...          ...          ...
# 1679  2007  2280.769906  Yemen, Rep.
# 1680  1952  1147.388831       Zambia
# 1691  2007  1271.211593       Zambia
# 1692  1952   406.884115     Zimbabwe
# 1703  2007   469.709298     Zimbabwe
#
# [284 rows x 3 columns]

# %%
subset_yr = subset_yr.pivot_table(values='gdpPercap',
                                  index='Year', columns='Country')
subset_yr
# Out:
# Country  Afghanistan      Albania      Algeria       Angola     Argentina  \
# Year
# 1952      779.445314  1601.056136  2449.008185  3520.610273   5911.315053
# 2007      974.580338  5937.029526  6223.367465  4797.231267  12779.379640
#
# Country    Australia       Austria       Bahrain   Bangladesh       Belgium  \
# Year
# 1952     10039.59564   6137.076492   9867.084765   684.244172   8343.105127
# 2007     34435.36744  36126.492700  29796.048340  1391.253792  33692.605080
#
# Country  ...       Uganda  United Kingdom  United States       Uruguay  \
# Year     ...
# 1952     ...   734.753484     9979.508487    13990.48208   5716.766744
# 2007     ...  1056.380121    33203.261280    42951.65309  10611.462990
#
# Country     Venezuela      Vietnam  West Bank and Gaza  Yemen, Rep.  \
# Year
# 1952      7689.799761   605.066492         1515.592329   781.717576
# 2007     11415.805690  2441.576404         3025.349798  2280.769906
#
# Country       Zambia    Zimbabwe
# Year
# ...

# %%
plt.hist(subset_yr, bins=100, stacked=True, 
         alpha= 0.8, label=subset_yr.index.values);
plt.legend()
plt.xlim(0,60000)
# Out:
# (0, 60000)
